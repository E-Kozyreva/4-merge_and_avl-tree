# %% [markdown]
# ### Test data

# %%
arr = [345, -1, 14, 789, 23, 76, 55, -9, 4, 6 , 122, 665, 2342, 90, 3, 5]

# %% [markdown]
# ### Avl-tree

# %%
class Node(object):

    def __init__(self, key: int):
        self.key = key
        self.left = None 
        self.right = None 


class AVLTree(object):

    def __init__(self, *args):
        self.node = None 
        self.height = -1  
        self.balance = 0; 
        
        if len(args) == 1: 
            for i in args[0]: 
                self.insert(i)

                
    def height(self) -> int:
        return self.node.height if self.node else 0
    

    def is_leaf(self) -> bool:
        return (self.height == 0) 
    

    def insert(self, key: int) -> bool:
        tree = self.node
        newnode = Node(key)
        
        if tree == None:
            self.node = newnode 
            self.node.left = AVLTree() 
            self.node.right = AVLTree()
            print("Inserted key [" + str(key) + "]")
        elif key < tree.key: 
            self.node.left.insert(key)
        elif key > tree.key: 
            self.node.right.insert(key)
        else: 
            print("Key [" + str(key) + "] already in tree.")
        self.rebalance() 
        
    
    def rebalance(self) -> None:
        self.update_heights(False)
        self.update_balances(False)

        while self.balance < -1 or self.balance > 1: 
            if self.balance > 1:
                if self.node.left.balance < 0:  
                    self.node.left.lrotate() 
                    self.update_heights()
                    self.update_balances()
                self.rrotate()
                self.update_heights()
                self.update_balances()
                
            if self.balance < -1:
                if self.node.right.balance > 0:  
                    self.node.right.rrotate() 
                    self.update_heights()
                    self.update_balances()
                self.lrotate()
                self.update_heights()
                self.update_balances()


    def rrotate(self) -> None:
        print('Rotating ' + str(self.node.key) + ' right') 
        A = self.node 
        B = self.node.left.node 
        T = B.right.node 
        
        self.node = B 
        B.right.node = A 
        A.left.node = T 

    
    def lrotate(self) -> None:
        print('Rotating ' + str(self.node.key) + ' left') 
        A = self.node 
        B = self.node.right.node 
        T = B.left.node 
        
        self.node = B 
        B.left.node = A 
        A.right.node = T 

    
    def rl_rotate(self) -> None:
        print('Rotating ' + str(self.node.key) + ' right then left')
        self.node.right.rrotate()
        self.lrotate()

    
    def lr_rotate(self) -> None:
        print('Rotating ' + str(self.node.key) + ' left then right')
        self.node.left.lrotate()
        self.rrotate()
        
            
    def update_heights(self, recurse=True) -> None:
        if not self.node == None: 
            if recurse: 
                if self.node.left != None: 
                    self.node.left.update_heights()
                if self.node.right != None:
                    self.node.right.update_heights()
            self.height = max(self.node.left.height, self.node.right.height) + 1 
        else: 
            self.height = -1 

       
    def update_balances(self, recurse=True) -> None:
        if not self.node == None: 
            if recurse: 
                if self.node.left != None: 
                    self.node.left.update_balances()
                if self.node.right != None:
                    self.node.right.update_balances()
            self.balance = self.node.left.height - self.node.right.height 
        else: 
            self.balance = 0 


    def delete(self, key: int) -> None:
        if self.node != None: 
            if self.node.key == key: 
                print("Deleting ... " + str(key))  
                if self.node.left.node == None and self.node.right.node == None:
                    self.node = None
                elif self.node.left.node == None: 
                    self.node = self.node.right.node
                elif self.node.right.node == None: 
                    self.node = self.node.left.node
                else:  
                    replacement = self.logical_successor(self.node)
                    if replacement != None: # sanity check 
                        print("Found replacement for " + str(key) + " -> " + str(replacement.key))  
                        self.node.key = replacement.key 
                        self.node.right.delete(replacement.key)
                self.rebalance()
                return  
            elif key < self.node.key: 
                self.node.left.delete(key)  
            elif key > self.node.key: 
                self.node.right.delete(key)
            self.rebalance()
        else: 
            return 


    def logical_predecessor(self, node):
        node = node.left.node 
        if node != None: 
            while node.right != None:
                if node.right.node == None: 
                    return node 
                else: 
                    node = node.right.node  
        return node 
    

    def logical_successor(self, node):
        node = node.right.node  
        if node != None:  
            while node.left != None:
                print("LS: traversing: " + str(node.key))
                if node.left.node == None: 
                    return node 
                else: 
                    node = node.left.node  
        return node 


    def check_balanced(self) -> bool:
        if self == None or self.node == None: 
            return True
        
        self.update_heights()
        self.update_balances()
        return ((abs(self.balance) < 2) and self.node.left.check_balanced() and self.node.right.check_balanced())  
        

    def inorder_traverse(self) -> list:
        if self.node == None:
            return [] 
        
        inlist = [] 
        l = self.node.left.inorder_traverse()
        for i in l: 
            inlist.append(i) 

        inlist.append(self.node.key)

        l = self.node.right.inorder_traverse()
        for i in l: 
            inlist.append(i) 
    
        return inlist 


    def display(self, level=0, pref='') -> None:  
        self.update_heights()   
        self.update_balances()
        if(self.node != None): 
            print('-' * level * 2, pref, self.node.key, "[" + str(self.height) + ":" + str(self.balance) + "]", 'L' if self.is_leaf() else ' ')
            if self.node.left != None: 
                self.node.left.display(level + 1, '<')
            if self.node.left != None:
                self.node.right.display(level + 1, '>')

# %% [markdown]
# ### Output

# %%
tree = AVLTree()
print("----- Inserting -------")
for elem in arr: 
    tree.insert(elem)
    
tree.display()

print("----- Deleting -------")
tree.delete(3)
tree.delete(4)
tree.delete(5) 
tree.display()

print("Input            :", arr)
print("deleting ...       ", 3)
print("deleting ...       ", 4)
print("Inorder traversal:", tree.inorder_traverse())
# Out:
# ----- Inserting -------
# Inserted key [345]
# Inserted key [-1]
# Inserted key [14]
# Rotating -1 left
# Rotating 345 right
# Inserted key [789]
# Inserted key [23]
# Inserted key [76]
# Rotating 345 right
# Rotating 14 left
# Inserted key [55]
# Inserted key [-9]
# Rotating 14 right
# Inserted key [4]
# Inserted key [6]
# Rotating 4 left
# Rotating 14 right
# Inserted key [122]
# Inserted key [665]
# Inserted key [2342]
# Inserted key [90]
# Inserted key [3]
# Rotating 6 right
# Rotating -1 left
# Inserted key [5]
#   23 [4:-1]
# -- < 4 [2:0]
# ---- < -1 [1:0]
# ------ < -9 [0:0] L
# ------ > 3 [0:0] L
# ---- > 6 [1:0]
# ------ < 5 [0:0] L
# ------ > 14 [0:0] L
# -- > 345 [3:1]
# ---- < 76 [2:-1]
# ------ < 55 [0:0] L
# ------ > 122 [1:1]
# -------- < 90 [0:0] L
# ---- > 789 [1:0]
# ------ < 665 [0:0] L
# ------ > 2342 [0:0] L
# ----- Deleting -------
# Deleting ... 3
# Deleting ... 4
# LS: traversing: 6
# LS: traversing: 5
# Found replacement for 4 -> 5
# Deleting ... 5
# Deleting ... 5
# LS: traversing: 6
# Found replacement for 5 -> 6
# Deleting ... 6
#   23 [4:-1]
# -- < 6 [2:1]
# ---- < -1 [1:1]
# ------ < -9 [0:0] L
# ---- > 14 [0:0] L
# -- > 345 [3:1]
# ---- < 76 [2:-1]
# ------ < 55 [0:0] L
# ------ > 122 [1:1]
# -------- < 90 [0:0] L
# ---- > 789 [1:0]
# ------ < 665 [0:0] L
# ------ > 2342 [0:0] L
# Input            : [345, -1, 14, 789, 23, 76, 55, -9, 4, 6, 122, 665, 2342, 90, 3, 5]
# deleting ...        3
# deleting ...        4
# Inorder traversal: [-9, -1, 6, 14, 23, 55, 76, 90, 122, 345, 665, 789, 2342]
